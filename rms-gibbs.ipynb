# %%
print("hello guys")
# Out:
# hello guys

# %%
# read input file
lines = [];
with open('input.txt') as inputFile:
    lines = inputFile.readlines();
    
count = 0
for line in lines:
    count += 1
    print(f'line {count}: {line}')

# %%
# take k value from the user
kValue = input("Please enter a k value : /n");
